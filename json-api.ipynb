# %% [markdown]
# # Using APIs and JSON Data

# %% [markdown]
# ![more_data](https://media.giphy.com/media/3o7TKSx0g7RqRniGFG/giphy.gif)

# %% [markdown]
# ## Agenda
#
# * Introduce JSON Schemas and learn how to interact with them
# * Introduce APIs.
# * Walk through how to make an API request.
# * Practice making API requests and Parsing the data.

# %% [markdown]
# # Scenario
#
# ![giant_burger](https://media.giphy.com/media/gF1qyNYa6kwSXfzuAX/giphy.gif)
#
# You are planning to open an upscale hamburger restaurant in Chicago to rival Au Cheval.  Your slogan will be "The best burger in less than 4 hours." It is an inside-joke, thus mysterious and good for business.  You are looking to gain insight into burger shop density across Chicago using the Yelp API.  You also recognize that good music is very important when opening a restaurant, and want to gather data about what to play using Spotify data.

# %% [markdown]
# # What is a JSON file?
#
# JSON stands for Java Script Object Notation.
#
# JSON objects are one way that data is transmitted over the web.  It is noteable for being lightweight, which makes it [preferred](https://stackoverflow.com/questions/383692/what-is-json-and-why-would-i-use-it), generally, over XML.
#
# When you have time, check out this [link](https://www.json.org/json-en.html) to the JSON website.

# %% [markdown]
# ## Format
#
# JSON objects look similar to Python dictionaries, and you will see that they can be interacted with in a similar way.  They are both objects that contain information within open and closed curly braces.  JSON's look much like nested dictionaries.

# %% [markdown]
# ### What is the difference between a JSON and a python dictionary?

# %%
# Your answer here

# %% [markdown]
# ## Take a second...
# and open up the JSON file in the data folder.  If you are in Jupyter Lab, control-click and open with the editor.
#
# Get familiar with the structure, and locate where the bulk of the data is held.

# %% [markdown]
# ## Loading the JSON file
#
# The new_releases.json file resulted from a query to the Spotify API. It represents 20 new releases that came out on May, 19th. The plan is to ping the API each day for new releases, and build a playlist that rotates through the songs off each album.
#
# Let's begin by importing the json package, opening a file with python's built in function, and then loading that data in.

# %%
import json
import pandas as pd
f = open('data/new_releases.json')
data = json.load(f)

# %% [markdown]
# The Spotify API returned the data in the form of JSON object, which the json module transforms into a Python object.
# ![drake_dancing_weird](https://media.giphy.com/media/3o85xJohCZUc524lSU/giphy.gif)

# %% [markdown]
# ## Exploring JSON Schemas
#
# Recall that JSON files have a nested structure. The most granular level of raw data will be individual numbers (float/int) and strings. These in turn will be stored in the equivalent of python lists and dictionaries. Because these can be combined, we'll start exploring by checking the type of our root object, and start mapping out the hierarchy of the json file.

# %% [markdown]
# ## Quick Q:
# if I run <br>
# `type(data)`<br>
# what will the output be?

# %%
# your answer here

# %% [markdown]
# As you can see, in this case, the first level of the hierarchy is a <>. Let's explore what keys are within this:

# %%
data.keys()
# Out:
# dict_keys(['albums'])

# %% [markdown]
# In this case, there is only a single key, 'albums', so we'll continue on down the pathway exploring and mapping out the hierarchy. Once again, let's start by checking the type of this nested data structure.

# %%
type(data['albums'])
# Out:
# dict

# %%
data['albums'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %% [markdown]
# At this point, things are starting to look something like this:
#
# ![](images/json_diagram1.JPG)

# %% [markdown]
# At this point, if we were to continue checking individual data types, we have a lot to go through. To simplify this, let's use a for loop:

# %%
for key,value in data['albums'].items():
    print(key, type(value))
# Out:
# href <class 'str'>
# items <class 'list'>
# limit <class 'int'>
# next <class 'str'>
# offset <class 'int'>
# previous <class 'NoneType'>
# total <class 'int'>

# %% [markdown]
# Adding this to our diagram we now have something like this:
# ![](images/json_diagram2.JPG)

# %% [markdown]
# Let's look at the type of items:

# %%
type(data['albums']['items'])
# Out:
# list

# %% [markdown]
# That is a json array, whose python equivalent is the list

# %%
data['albums']['items']
# Out:
# [{'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'},
#     'href': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i',
#     'id': '1RyvyyTE3xzB2ZywiAwp0i',
#     'name': 'Future',
#     'type': 'artist',
#     'uri': 'spotify:artist:1RyvyyTE3xzB2ZywiAwp0i'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4bNPOFOzxGhF5jhfIK6lit'},
#   'href': 'https://api.spotify.com/v1/albums/4bNPOFOzxGhF5jhfIK6lit',
#   'id': '4bNPOFOzxGhF5jhfIK6lit',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273935d8d5369bc55e74a39303e',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02935d8d5369bc55e74a39303e',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851935d8d5369bc55e74a39303e',
#     'width': 64}],
#   'name': 'High Off Life',
#   'release_date': '2020-05-15',
#   'release_date_precision': 'day',
#   'total_tracks': 21,
#   'type': 'album',
#   'uri': 'spotify:album:4bNPOFOzxGhF5jhfIK6lit'},
#  {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'},
#     'href': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4',
#     'id': '23fqKkggKUBHNkbKtXEls4',
#     'name': 'Kygo',
#     'type': 'artist',
#     'uri': 'spotify:artist:23fqKkggKUBHNkbKtXEls4'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pwc4xIPtQLFEnJriah9YJ'},
#     'href': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ',
#     'id': '5Pwc4xIPtQLFEnJriah9YJ',
#     'name': 'OneRepublic',
#     'type': 'artist',
#     'uri': 'spotify:artist:5Pwc4xIPtQLFEnJriah9YJ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3LhriqAiHJYw7rxvtlkvQc'},
#   'href': 'https://api.spotify.com/v1/albums/3LhriqAiHJYw7rxvtlkvQc',
#   'id': '3LhriqAiHJYw7rxvtlkvQc',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273479856767f92aab97c956704',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02479856767f92aab97c956704',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851479856767f92aab97c956704',
#     'width': 64}],
#   'name': 'Lose Somebody',
#   'release_date': '2020-05-15',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:3LhriqAiHJYw7rxvtlkvQc'},
#  {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2Zg5xZo3WwIoAZys8OcUpG'},
#   'href': 'https://api.spotify.com/v1/albums/2Zg5xZo3WwIoAZys8OcUpG',
#   'id': '2Zg5xZo3WwIoAZys8OcUpG',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2732e819e33b9703a8b3fc85a35',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e022e819e33b9703a8b3fc85a35',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048512e819e33b9703a8b3fc85a35',
#     'width': 64}],
#   'name': 'SCOOB! The Album',
#   'release_date': '2020-05-15',
#   'release_date_precision': 'day',
#   'total_tracks': 12,
#   'type': 'album',
#   'uri': 'spotify:album:2Zg5xZo3WwIoAZys8OcUpG'},
#  {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#     'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#     'id': '6jJ0s89eD6GaHleKKya26X',
#     'name': 'Katy Perry',
#     'type': 'artist',
#     'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2m5J1DUH7hJpPSOromIqpN'},
#   'href': 'https://api.spotify.com/v1/albums/2m5J1DUH7hJpPSOromIqpN',
#   'id': '2m5J1DUH7hJpPSOromIqpN',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2738df6751bad8ab6b5c928dba3',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e028df6751bad8ab6b5c928dba3',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048518df6751bad8ab6b5c928dba3',
#     'width': 64}],
#   'name': 'Daisies',
#   'release_date': '2020-05-15',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:2m5J1DUH7hJpPSOromIqpN'},
#  {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6AgTAQt8XS6jRWi4sX7w49'},
#     'href': 'https://api.spotify.com/v1/artists/6AgTAQt8XS6jRWi4sX7w49',
#     'id': '6AgTAQt8XS6jRWi4sX7w49',
#     'name': 'Polo G',
#     'type': 'artist',
#     'uri': 'spotify:artist:6AgTAQt8XS6jRWi4sX7w49'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/39xhYyNNDatQtgKw2KdXMz'},
#   'href': 'https://api.spotify.com/v1/albums/39xhYyNNDatQtgKw2KdXMz',
#   'id': '39xhYyNNDatQtgKw2KdXMz',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273339f780dfdbc38558ea0761d',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02339f780dfdbc38558ea0761d',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851339f780dfdbc38558ea0761d',
#     'width': 64}],
#   'name': 'THE GOAT',
#   'release_date': '2020-05-15',
#   'release_date_precision': 'day',
#   'total_tracks': 16,
#   'type': 'album',
#   'uri': 'spotify:album:39xhYyNNDatQtgKw2KdXMz'},
#  {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#     'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#     'id': '7gOdHgIoIKoe4i9Tta6qdD',
#     'name': 'Jonas Brothers',
#     'type': 'artist',
#     'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#     'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#     'id': '790FomKkXshlbRYZFtlgla',
#     'name': 'KAROL G',
#     'type': 'artist',
#     'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0i96PtPJV65ddxsfMfo45F'},
#   'href': 'https://api.spotify.com/v1/albums/0i96PtPJV65ddxsfMfo45F',
#   'id': '0i96PtPJV65ddxsfMfo45F',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2733b3cd45dfa6f779c01d63fdb',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e023b3cd45dfa6f779c01d63fdb',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048513b3cd45dfa6f779c01d63fdb',
#     'width': 64}],
#   'name': 'XV',
#   'release_date': '2020-05-15',
#   'release_date_precision': 'day',
#   'total_tracks': 2,
#   'type': 'album',
#   'uri': 'spotify:album:0i96PtPJV65ddxsfMfo45F'},
#  {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25uiPmTg16RbhZWAqwLBy5'},
#     'href': 'https://api.spotify.com/v1/artists/25uiPmTg16RbhZWAqwLBy5',
#     'id': '25uiPmTg16RbhZWAqwLBy5',
#     'name': 'Charli XCX',
#     'type': 'artist',
#     'uri': 'spotify:artist:25uiPmTg16RbhZWAqwLBy5'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3a9qH2VEsSiOZvMrjaS0Nu'},
#   'href': 'https://api.spotify.com/v1/albums/3a9qH2VEsSiOZvMrjaS0Nu',
#   'id': '3a9qH2VEsSiOZvMrjaS0Nu',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273664e38c99d077cc52ab48914',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02664e38c99d077cc52ab48914',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851664e38c99d077cc52ab48914',
#     'width': 64}],
#   'name': "how i'm feeling now",
#   'release_date': '2020-05-15',
#   'release_date_precision': 'day',
#   'total_tracks': 11,
#   'type': 'album',
#   'uri': 'spotify:album:3a9qH2VEsSiOZvMrjaS0Nu'},
#  {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2jku7tDXc6XoB6MO2hFuqg'},
#     'href': 'https://api.spotify.com/v1/artists/2jku7tDXc6XoB6MO2hFuqg',
#     'id': '2jku7tDXc6XoB6MO2hFuqg',
#     'name': 'Tory Lanez',
#     'type': 'artist',
#     'uri': 'spotify:artist:2jku7tDXc6XoB6MO2hFuqg'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3lalGt6k7JM3tIji1Xbgmk'},
#   'href': 'https://api.spotify.com/v1/albums/3lalGt6k7JM3tIji1Xbgmk',
#   'id': '3lalGt6k7JM3tIji1Xbgmk',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273c2ebaf0c84eb77f358d958bc',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02c2ebaf0c84eb77f358d958bc',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851c2ebaf0c84eb77f358d958bc',
#     'width': 64}],
#   'name': 'Temperature Rising',
#   'release_date': '2020-05-15',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:3lalGt6k7JM3tIji1Xbgmk'},
#  {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ueoLVCXQ948OfhVvAy3Nn'},
#     'href': 'https://api.spotify.com/v1/artists/2ueoLVCXQ948OfhVvAy3Nn',
#     'id': '2ueoLVCXQ948OfhVvAy3Nn',
#     'name': 'Perfume Genius',
#     'type': 'artist',
#     'uri': 'spotify:artist:2ueoLVCXQ948OfhVvAy3Nn'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6daEdTBi1hyFQgmsnR7oRr'},
#   'href': 'https://api.spotify.com/v1/albums/6daEdTBi1hyFQgmsnR7oRr',
#   'id': '6daEdTBi1hyFQgmsnR7oRr',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2739af34850f5125ef195d6101a',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e029af34850f5125ef195d6101a',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048519af34850f5125ef195d6101a',
#     'width': 64}],
#   'name': 'Set My Heart On Fire Immediately',
#   'release_date': '2020-05-15',
#   'release_date_precision': 'day',
#   'total_tracks': 13,
#   'type': 'album',
#   'uri': 'spotify:album:6daEdTBi1hyFQgmsnR7oRr'},
#  {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7rkW85dBwwrJtlHRDkJDAC'},
#     'href': 'https://api.spotify.com/v1/artists/7rkW85dBwwrJtlHRDkJDAC',
#     'id': '7rkW85dBwwrJtlHRDkJDAC',
#     'name': 'NAV',
#     'type': 'artist',
#     'uri': 'spotify:artist:7rkW85dBwwrJtlHRDkJDAC'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2kx4l1OQNT2JXLld9HJDIh'},
#   'href': 'https://api.spotify.com/v1/albums/2kx4l1OQNT2JXLld9HJDIh',
#   'id': '2kx4l1OQNT2JXLld9HJDIh',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273b9c89bb14d58ea3150bd435d',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02b9c89bb14d58ea3150bd435d',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851b9c89bb14d58ea3150bd435d',
#     'width': 64}],
#   'name': 'Good Intentions (Brown Boy 2 Deluxe Version)',
#   'release_date': '2020-05-11',
#   'release_date_precision': 'day',
#   'total_tracks': 32,
#   'type': 'album',
#   'uri': 'spotify:album:2kx4l1OQNT2JXLld9HJDIh'},
#  {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6oMuImdp5ZcFhWP0ESe6mG'},
#     'href': 'https://api.spotify.com/v1/artists/6oMuImdp5ZcFhWP0ESe6mG',
#     'id': '6oMuImdp5ZcFhWP0ESe6mG',
#     'name': 'Migos',
#     'type': 'artist',
#     'uri': 'spotify:artist:6oMuImdp5ZcFhWP0ESe6mG'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3PASWLvNfvfMF68dDznEgK'},
#   'href': 'https://api.spotify.com/v1/albums/3PASWLvNfvfMF68dDznEgK',
#   'id': '3PASWLvNfvfMF68dDznEgK',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2739325c863d9139cc2d507421b',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e029325c863d9139cc2d507421b',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048519325c863d9139cc2d507421b',
#     'width': 64}],
#   'name': 'Racks 2 Skinny',
#   'release_date': '2020-05-11',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:3PASWLvNfvfMF68dDznEgK'},
#  {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Zq7R5qmi58ByYyBQTlNuk'},
#     'href': 'https://api.spotify.com/v1/artists/5Zq7R5qmi58ByYyBQTlNuk',
#     'id': '5Zq7R5qmi58ByYyBQTlNuk',
#     'name': 'Lee Brice',
#     'type': 'artist',
#     'uri': 'spotify:artist:5Zq7R5qmi58ByYyBQTlNuk'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5LK5cCx0XdniivfZ91vOSv'},
#   'href': 'https://api.spotify.com/v1/albums/5LK5cCx0XdniivfZ91vOSv',
#   'id': '5LK5cCx0XdniivfZ91vOSv',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27306ae99421702f8a9d881e268',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0206ae99421702f8a9d881e268',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485106ae99421702f8a9d881e268',
#     'width': 64}],
#   'name': 'One Of Them Girls',
#   'release_date': '2020-05-15',
#   'release_date_precision': 'day',
#   'total_tracks': 2,
#   'type': 'album',
#   'uri': 'spotify:album:5LK5cCx0XdniivfZ91vOSv'},
#  {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2o5jDhtHVPhrJdv3cEQ99Z'},
#     'href': 'https://api.spotify.com/v1/artists/2o5jDhtHVPhrJdv3cEQ99Z',
#     'id': '2o5jDhtHVPhrJdv3cEQ99Z',
#     'name': 'Tiësto',
#     'type': 'artist',
#     'uri': 'spotify:artist:2o5jDhtHVPhrJdv3cEQ99Z'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6CIslPQSknp875cigkhKJC'},
#   'href': 'https://api.spotify.com/v1/albums/6CIslPQSknp875cigkhKJC',
#   'id': '6CIslPQSknp875cigkhKJC',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2739759d6dfa2c19091814fccb3',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e029759d6dfa2c19091814fccb3',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048519759d6dfa2c19091814fccb3',
#     'width': 64}],
#   'name': 'The London Sessions',
#   'release_date': '2020-05-15',
#   'release_date_precision': 'day',
#   'total_tracks': 13,
#   'type': 'album',
#   'uri': 'spotify:album:6CIslPQSknp875cigkhKJC'},
#  {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6pBNfggcZZDCmb0p92OnGn'},
#     'href': 'https://api.spotify.com/v1/artists/6pBNfggcZZDCmb0p92OnGn',
#     'id': '6pBNfggcZZDCmb0p92OnGn',
#     'name': 'Chase Rice',
#     'type': 'artist',
#     'uri': 'spotify:artist:6pBNfggcZZDCmb0p92OnGn'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5XvXf3mdhShyLZhoJYR74q'},
#   'href': 'https://api.spotify.com/v1/albums/5XvXf3mdhShyLZhoJYR74q',
#   'id': '5XvXf3mdhShyLZhoJYR74q',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2735f6b892b478747a769252650',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e025f6b892b478747a769252650',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048515f6b892b478747a769252650',
#     'width': 64}],
#   'name': 'The Album, Pt. II',
#   'release_date': '2020-05-15',
#   'release_date_precision': 'day',
#   'total_tracks': 4,
#   'type': 'album',
#   'uri': 'spotify:album:5XvXf3mdhShyLZhoJYR74q'},
#  {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1caBfBEapzw8z2Qz9q0OaQ'},
#     'href': 'https://api.spotify.com/v1/artists/1caBfBEapzw8z2Qz9q0OaQ',
#     'id': '1caBfBEapzw8z2Qz9q0OaQ',
#     'name': 'Asking Alexandria',
#     'type': 'artist',
#     'uri': 'spotify:artist:1caBfBEapzw8z2Qz9q0OaQ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5VKKXDvYuJmRc2UQHCwNQK'},
#   'href': 'https://api.spotify.com/v1/albums/5VKKXDvYuJmRc2UQHCwNQK',
#   'id': '5VKKXDvYuJmRc2UQHCwNQK',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273d30ebbcdf987ab5273abdd8d',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02d30ebbcdf987ab5273abdd8d',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851d30ebbcdf987ab5273abdd8d',
#     'width': 64}],
#   'name': 'Like A House On Fire',
#   'release_date': '2020-05-15',
#   'release_date_precision': 'day',
#   'total_tracks': 15,
#   'type': 'album',
#   'uri': 'spotify:album:5VKKXDvYuJmRc2UQHCwNQK'},
#  {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7d3WFRME3vBY2cgoP38RDo'},
#     'href': 'https://api.spotify.com/v1/artists/7d3WFRME3vBY2cgoP38RDo',
#     'id': '7d3WFRME3vBY2cgoP38RDo',
#     'name': 'Lil Skies',
#     'type': 'artist',
#     'uri': 'spotify:artist:7d3WFRME3vBY2cgoP38RDo'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3cVy1WTjSAVpzUc7MVCTLu'},
#   'href': 'https://api.spotify.com/v1/albums/3cVy1WTjSAVpzUc7MVCTLu',
#   'id': '3cVy1WTjSAVpzUc7MVCTLu',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273f7571dc32332081426ab3818',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02f7571dc32332081426ab3818',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851f7571dc32332081426ab3818',
#     'width': 64}],
#   'name': 'Riot',
#   'release_date': '2020-05-13',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:3cVy1WTjSAVpzUc7MVCTLu'},
#  {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55fhWPvDiMpLnE4ZzNXZyW'},
#     'href': 'https://api.spotify.com/v1/artists/55fhWPvDiMpLnE4ZzNXZyW',
#     'id': '55fhWPvDiMpLnE4ZzNXZyW',
#     'name': 'Noah Cyrus',
#     'type': 'artist',
#     'uri': 'spotify:artist:55fhWPvDiMpLnE4ZzNXZyW'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5Gn3fFzlWL89j0hGumtXb5'},
#   'href': 'https://api.spotify.com/v1/albums/5Gn3fFzlWL89j0hGumtXb5',
#   'id': '5Gn3fFzlWL89j0hGumtXb5',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2737f66b73bd6e86f4c8d2a7692',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e027f66b73bd6e86f4c8d2a7692',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048517f66b73bd6e86f4c8d2a7692',
#     'width': 64}],
#   'name': 'THE END OF EVERYTHING',
#   'release_date': '2020-05-15',
#   'release_date_precision': 'day',
#   'total_tracks': 8,
#   'type': 'album',
#   'uri': 'spotify:album:5Gn3fFzlWL89j0hGumtXb5'},
#  {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6C1ohJrd5VydigQtaGy5Wa'},
#     'href': 'https://api.spotify.com/v1/artists/6C1ohJrd5VydigQtaGy5Wa',
#     'id': '6C1ohJrd5VydigQtaGy5Wa',
#     'name': 'Joyner Lucas',
#     'type': 'artist',
#     'uri': 'spotify:artist:6C1ohJrd5VydigQtaGy5Wa'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/41qil2VaGbD194gaEcmmyx'},
#     'href': 'https://api.spotify.com/v1/artists/41qil2VaGbD194gaEcmmyx',
#     'id': '41qil2VaGbD194gaEcmmyx',
#     'name': 'Will Smith',
#     'type': 'artist',
#     'uri': 'spotify:artist:41qil2VaGbD194gaEcmmyx'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3tOe6XM8LmRA5vDAaMqp8e'},
#   'href': 'https://api.spotify.com/v1/albums/3tOe6XM8LmRA5vDAaMqp8e',
#   'id': '3tOe6XM8LmRA5vDAaMqp8e',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2734ac196312c24faedb76a345e',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e024ac196312c24faedb76a345e',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048514ac196312c24faedb76a345e',
#     'width': 64}],
#   'name': 'Will (Remix)',
#   'release_date': '2020-05-15',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:3tOe6XM8LmRA5vDAaMqp8e'},
#  {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Xgp2XMz1fhVYe7i6yNAax'},
#     'href': 'https://api.spotify.com/v1/artists/6Xgp2XMz1fhVYe7i6yNAax',
#     'id': '6Xgp2XMz1fhVYe7i6yNAax',
#     'name': 'Trippie Redd',
#     'type': 'artist',
#     'uri': 'spotify:artist:6Xgp2XMz1fhVYe7i6yNAax'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2HPaUgqeutzr3jx5a9WyDV'},
#     'href': 'https://api.spotify.com/v1/artists/2HPaUgqeutzr3jx5a9WyDV',
#     'id': '2HPaUgqeutzr3jx5a9WyDV',
#     'name': 'PARTYNEXTDOOR',
#     'type': 'artist',
#     'uri': 'spotify:artist:2HPaUgqeutzr3jx5a9WyDV'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7rcMHNqNbQxF5TaPMHFoKu'},
#   'href': 'https://api.spotify.com/v1/albums/7rcMHNqNbQxF5TaPMHFoKu',
#   'id': '7rcMHNqNbQxF5TaPMHFoKu',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273de32a6662a7db272328f4761',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02de32a6662a7db272328f4761',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851de32a6662a7db272328f4761',
#     'width': 64}],
#   'name': 'Excitement',
#   'release_date': '2020-05-15',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:7rcMHNqNbQxF5TaPMHFoKu'},
#  {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3NPpFNZtSTHheNBaWC82rB'},
#     'href': 'https://api.spotify.com/v1/artists/3NPpFNZtSTHheNBaWC82rB',
#     'id': '3NPpFNZtSTHheNBaWC82rB',
#     'name': 'X Ambassadors',
#     'type': 'artist',
#     'uri': 'spotify:artist:3NPpFNZtSTHheNBaWC82rB'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0pCNk4D3E2xtszsm6hMsWr'},
#     'href': 'https://api.spotify.com/v1/artists/0pCNk4D3E2xtszsm6hMsWr',
#     'id': '0pCNk4D3E2xtszsm6hMsWr',
#     'name': 'K.Flay',
#     'type': 'artist',
#     'uri': 'spotify:artist:0pCNk4D3E2xtszsm6hMsWr'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4ZgQDCtRqZlhLswVS6MHN4'},
#     'href': 'https://api.spotify.com/v1/artists/4ZgQDCtRqZlhLswVS6MHN4',
#     'id': '4ZgQDCtRqZlhLswVS6MHN4',
#     'name': 'grandson',
#     'type': 'artist',
#     'uri': 'spotify:artist:4ZgQDCtRqZlhLswVS6MHN4'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2JQbWWpYG6kKppiD6z2FwL'},
#   'href': 'https://api.spotify.com/v1/albums/2JQbWWpYG6kKppiD6z2FwL',
#   'id': '2JQbWWpYG6kKppiD6z2FwL',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273e420fab8e9ec9cf79c073a28',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02e420fab8e9ec9cf79c073a28',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851e420fab8e9ec9cf79c073a28',
#     'width': 64}],
#   'name': 'Zen (with K.Flay & grandson)',
#   'release_date': '2020-05-15',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:2JQbWWpYG6kKppiD6z2FwL'}]

# %% [markdown]
# We access the values as we would a list, as it has now been converted into one:

# %%
data['albums']['items'][0]['artists'][0]['name']
# Out:
# 'Future'

# %%
data['albums']['items'][1]['artists'][0]['name']
# Out:
# 'Kygo'

# %% [markdown]
# Because the JSON object is a dicitonary, we can create a dataframe from, like we have learned previously:

# %% [markdown]
# # Pair Programming
#
# Create a dataframe out of the items in the json output.
# Once you do so, you will notice that the artists column is not informative.
# Use a list comprehension to transform the content of artists to reflect the first artist listed in for each album.

# %%
# Your code here

# %%
#__SOLUTION__
df = pd.DataFrame(data['albums']['items'])
df['artists'] = [item['artists'][0]['name'] for item in data['albums']['items']]

# %% [markdown]
# ![Arby_pharrell_bighat](https://media.giphy.com/media/MDwql6xEUzyjS/giphy.gif)

# %% [markdown]
# ## What is an API?

# %%
# Unmute yourselves and discuss

# %% [markdown]
# **Application Program Interfaces**, or APIs, are commonly used to retrieve data from remote websites. Sites like Reddit, Twitter, and Facebook all offer certain data through their APIs.
#
# To use an API, you make a request to a remote web server, and retrieve the data you need.

# %% [markdown]
# Python has two built-in modules, `urllib` and `urllib2` to handle these requests but these can be very confusing  and the documentation is not clear.
#
# To make these things simpler, one easy-to-use third-party library, known as` Requests`, is what most developers prefer to use instead or urllib/urllib2. With this library, you can access content like web page headers, form data, files, and parameters via simple Python commands. It also allows you to access the response data in a simple way.

# %% [markdown]
# ![](images/logo.png)

# %% [markdown]
# Below is how you would install and import the requests library before making any requests.
# ```python
# # Uncomment and install requests if you dont have it already
# # conda install -c anaconda requests
#
# # Import requests to working environment
# import requests
# ```

# %%
#importing requests method
import requests

# %% [markdown]
# ## Brief interlude from our Hamburger business.  Maybe we should become astronauts instead
#
# ![astronaut_flossing](https://media.giphy.com/media/S99cgkURVO62qemEKM/giphy.gif)

# %% [markdown]
# ## The `.get()` Method
#
# Now we have requests library ready in our working environment, we can start making some requests using the `.get()` method as shown below:
#
#
# We can use a simple GET request to retrieve information from the OpenNotify API.
#
#
#
#
# OpenNotify has several API **endpoints**. An endpoint is a server route that is used to retrieve different data from the API. For example, the /comments endpoint on the Reddit API might retrieve information about comments, whereas the /users endpoint might retrieve data about users. To access them, you would add the endpoint to the base url of the API.

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
url = 'http://api.open-notify.org/iss-now.json'
response = requests.get(url)
# Print the status code of the response.

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'{"iss_position": {"longitude": "-55.2274", "latitude": "51.5232"}, "message": "success", "timestamp": 1589942229}'

# %%
# Let's check out who is in space right now!
url = 'http://api.open-notify.org/astros.json'
response = requests.get(url)
print(response.status_code)
data = response.json()
data.keys()
# Out:
# 200
# dict_keys(['number', 'message', 'people'])

# %%
# Quick Exercise: use a list comprehension to get the names of the people in space 
people = None

# %%
#__SOLUTION__
people = [person['name'] for person in data['people']]

# %%
print(f"There are {data['number']} people in the space station right now!")
print("Their names are {}".format(', '.join(people)))
# Out:
# There are 3 people in the space station right now!
# Their names are Chris Cassidy, Anatoly Ivanishin, Ivan Vagner

# %% [markdown]
# GET is by far the most used HTTP method. We can use GET request to retrieve data from any destination.
# GET is by far the most used HTTP method. We can use GET request to retrieve data from any destination.
#
# ## Status Codes
# The request we make may not be always successful. The best way is to check the status code which gets returned with the response. Here is how you would do this.

# %%
# Code here 
response.status_code == requests.codes.ok
# Out:
# True

# %%
# https://httpstatusdogs.com/

# %% [markdown]
# So this is a good check to see if our request was successful. Depending on the status of the web server, the access rights of the clients and availibility of requested information. A web server may return a number of status codes within the response. Wikipedia has an exhaustive details on all these codes. [Check them out here](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)

# %% [markdown]
# ### Common status codes
#
# * 200 — everything went okay, and the result has been returned (if any)
# * 301 — the server is redirecting you to a different endpoint. This can happen when a company switches domain names, or an endpoint name is changed.
# * 401 — the server thinks you’re not authenticated. This happens when you don’t send the right credentials to access an API (we’ll talk about authentication in a later post).
# * 400 — the server thinks you made a bad request. This can happen when you don’t send along the right data, among other things.
# * 403 — the resource you’re trying to access is forbidden — you don’t have the right permissions to see it.
# * 404 — the resource you tried to access wasn’t found on the server.

# %% [markdown]
# ### Hitting the right endpoint
#
# We’ll now make a GET request to http://api.open-notify.org/iss-pass.json.

# %%
url =  'http://api.open-notify.org/iss-pass.json'
response = requests.get(url)
response.status_code
# Out:
# 400

# %% [markdown]
# ## Response Contents
# We can check the returned information using `.text` property of the response object.
# ```python
# print (resp.text)
# ```

# %%
response = requests.get("http://api.open-notify.org/iss-pass.json")

# %%
# In this case, the text gives us a failure message and a reason
response.text
# Out:
# '{\n  "message": "failure", \n  "reason": "Latitude must be specified"\n}\n'

# %% [markdown]
# ### Query parameters
#
# If you look at the documentation for the OpenNotify API, we see that the ISS Pass endpoint requires two parameters.
#
# We can do this by adding an optional keyword argument, params, to our request. In this case, there are two parameters we need to pass:
#
# * lat — The latitude of the location we want.
# * lon — The longitude of the location we want.
# We can make a dictionary with these parameters, and then pass them into the requests.get function.
#
# We can also do the same thing directly by adding the query parameters to the url, like this: http://api.open-notify.org/iss-pass.json?lat=40.71&lon=-74.
#
# It’s almost always preferable to setup the parameters as a dictionary, because requests takes care of some things that come up, like properly formatting the query parameters.
#
# We’ll make a request using the coordinates of New York City, and see what response we get.

# %% [markdown]
# We can add parameters to the get method in the form of a dictionary.  In this instance, the dictionary parameter has two keys, lat and long.
# Help me code out the correct request.

# %%
# Our code here


# Print the content of the response (the data the server returned)
print(response.content)
# This gets the same data as the command aboveresponse = requests.get("http://api.open-notify.org/iss-pass.json?lat=40.71&lon=-74")
# Out:
# b'{\n  "message": "failure", \n  "reason": "Latitude must be specified"\n}\n'

# %%
#__SOLUTION__
# Set up the parameters we want to pass to the API.
# This is the latitude and longitude of New York City.
parameters = {"lat": 40.71, "lon": -74}


# Make a get request with the parameters.
response = requests.get("http://api.open-notify.org/iss-pass.json", params = parameters)

# %%
# let's change that timestamp to something readable
from datetime import datetime

# %%
datetime.fromtimestamp(response.json()['response'][3]['risetime'])
# Out:
# datetime.datetime(2020, 5, 20, 2, 20, 19)

# %% [markdown]
# So this returns a lot of information which by default is not really human understandable due to data encoding, HTML tags and other styling information that only a web browser can truly translate. In later lessons we shall look at how we can use ** Regular Expressions**  to clean this information and extract the required bits and pieces for analysis.
#
# ## Response Headers
# The response of an HTTP request can contain many headers that hold different bits of information. We can use `.headers` property of the response object to access the header information as shown below:

# %%
# Code here 
response.headers
# Out:
# {'Server': 'nginx/1.10.3', 'Date': 'Wed, 20 May 2020 02:37:14 GMT', 'Content-Type': 'application/json', 'Content-Length': '519', 'Connection': 'keep-alive', 'Via': '1.1 vegur'}

# %% [markdown]
# The content of the headers is our required element. You can see the key-value pairs holding various pieces of  information about the resource and request. Let's try to parse some of these values using the requests library:
#
# ```python
# print(response.headers['Content-Length'])  # length of the response
# print(response.headers['Date'])  # Date the response was sent
# print(response.headers['server'])   # Server type (google web service - GWS)
# ```

# %% [markdown]
# ## Back to the burgers

# %% [markdown]
# ## Generating Access Tokens
#
# As discussed, in order to use many APIs, one needs to use OAuth which requires an access token. As such, our first step will be to generate this login information so that we can start making some requests.
#
# With that, lets go grab an access token from an API site and make some API calls!
# Point your browser over to this [yelp page](https://www.yelp.com/developers/v3/manage_app) and start creating an app in order to obtain an api access token:

# %% [markdown]
# ![](./images/yelp_app.png)

# %% [markdown]
# You can either sign in to an existing Yelp account, or create a new one, if needed.
#
# On the page you see above, simply fill out some sample information such as "Flatiron Edu API Example" for the app name, or whatever floats your boat. Afterwards, you should be presented with an API key that you can use to make requests!
#
# With that, it's time to start making some api calls!

# %%
#As a general rule of thumb, don't store passwords in a main file. 
#Instead, you would normally store those passwords under a sub file like passwords.py which you would then import.
#Or even better, as an environment variable that could then be imported!
# Never upload you keys to Github, and don't print out the keys you imported, then upload to Github.

with open('/Users/johnmaxbarry/.ssh/yelp_api.json', 'rb') as read_file:
    keys = json.load(read_file)
    
client_id = keys['Client ID'] #Your client ID goes here (as a string) 
api_key = keys['API Key'] #Your api key goes here (as a string)

# %% [markdown]
# ## An Example Request with OAuth <a id="oauth_request"></a>
# https://www.yelp.com/developers/documentation/v3/get_started
#
# Let's look at an example request and dissect it into its consituent parts:

# %% [markdown]
# # Mix up
# Help me put this back in order

# %%
term = api_key
location = 'Hamburgers'
SEARCH_LIMIT = 10

url = ' '


headers = {
    'Authorization': 'Bearer {}'.format('Chicago IL'),
}

url_params = {
    'term': term.replace('https://api.yelp.com/v3/businesses/search', '+'),
    'location': location.replace(' ', '+'),
    'limit': SEARCH_LIMIT,
    'offset': 0
}
response = requests.get(url, headers=headers, params=url_params)
print(response)
data = response.json()
data.keys()
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-34-cc0aaae384d8> in <module>
#      16     'offset': 0
#      17 }
# ---> 18 response = requests.get(url, headers=headers, params=url_params)
#      19 print(response)
#      20 data = response.json()
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     517             hooks=hooks,
#     518         )
# --> 519         prep = self.prepare_request(req)
#     520
#     521         proxies = proxies or {}
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/sessions.py in prepare_request(self, request)
#     460             auth=merge_setting(auth, self.auth),
#     461             cookies=merged_cookies,
# --> 462             hooks=merge_hooks(request.hooks, self.hooks),
#     463         )
#     464         return p
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     311
#     312         self.prepare_method(method)
# --> 313         self.prepare_url(url, params)
#     314         self.prepare_headers(headers)
#     315         self.prepare_cookies(cookies)
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/requests/models.py in prepare_url(self, url, params)
#     385             error = error.format(to_native_string(url, 'utf8'))
#     386
# --> 387             raise MissingSchema(error)
#     388
#     389         if not host:
#
# MissingSchema: Invalid URL '': No schema supplied. Perhaps you meant http://?

# %%
#__SOLUTION__
term = 'Hamburgers'
location = 'Chicago IL'
SEARCH_LIMIT = 50

url = 'https://api.yelp.com/v3/businesses/search'

headers = {
    'Authorization': 'Bearer {}'.format(api_key),
}

url_params = {
    'term': term.replace(' ', '+'),
    'location': location.replace(' ', '+'),
    'limit': SEARCH_LIMIT,
    'offset': 0
}
response = requests.get(url, headers=headers, params=url_params)
print(response)
data = response.json()
data.keys()
# print(type(response.text))
# print(response.text[:1000])
# Out:
# <Response [200]>
# dict_keys(['businesses', 'total', 'region'])

# %%
data['businesses']
# Out:
# [{'id': '7Es7EbTy_s1btAdowLeiPQ',
#   'alias': 'small-cheval-chicago-2',
#   'name': 'Small Cheval',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/trovJn8N69SnqlaQyLfdUQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/small-cheval-chicago-2?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 1098,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.91282, 'longitude': -87.6815699},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1732 N Milwaukee Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60647',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1732 N Milwaukee Ave', 'Chicago, IL 60647']},
#   'phone': '+13129294580',
#   'display_phone': '(312) 929-4580',
#   'distance': 904.5895233591364},
#  {'id': 'xoi7Cw7FoknAx5p880RtWQ',
#   'alias': 'au-cheval-chicago',
#   'name': 'Au Cheval',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/a0yhvSJX_6i28iwS9egDFg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/au-cheval-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 7087,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.88466, 'longitude': -87.647668},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '800 W Randolph St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['800 W Randolph St', 'Chicago, IL 60607']},
#   'phone': '+13129294580',
#   'display_phone': '(312) 929-4580',
#   'distance': 3376.5984269738638},
#  {'id': 'GbC6XO60SlLnlIOTbJE-Ew',
#   'alias': 'fatsos-last-stand-chicago-2',
#   'name': "Fatso's Last Stand",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QLIfu26RCBMKnIQgyJ0uuQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fatsos-last-stand-chicago-2?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 791,
#   'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8959792096669,
#    'longitude': -87.6842580932541},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2258 W Chicago Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60622',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2258 W Chicago Ave', 'Chicago, IL 60622']},
#   'phone': '+17732453287',
#   'display_phone': '(773) 245-3287',
#   'distance': 1153.59118627344},
#  {'id': 'zEBMoH7ibF3YZrlowkv88A',
#   'alias': 'brgrbelly-chicago-3',
#   'name': 'BRGRBELLY',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ymFcfcJTQ0uVWvnCRWk4lQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/brgrbelly-chicago-3?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 543,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.9530335, 'longitude': -87.7709816},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '5739 W Irving Park Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60634',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['5739 W Irving Park Rd', 'Chicago, IL 60634']},
#   'phone': '+17732837880',
#   'display_phone': '(773) 283-7880',
#   'distance': 9370.400182708248},
#  {'id': 'Ydf5dgFsGhMSP61Ht7TekA',
#   'alias': 'butcher-and-the-burger-chicago',
#   'name': 'Butcher & The Burger',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XrovZl-f81Uzau4R3tegaQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/butcher-and-the-burger-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 1018,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.91787, 'longitude': -87.65423},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1021 W Armitage Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60614',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1021 W Armitage Ave', 'Chicago, IL 60614']},
#   'phone': '+17736973735',
#   'display_phone': '(773) 697-3735',
#   'distance': 2403.833029555007},
#  {'id': 'rp17Dfjdh7JR4GGZwj6nqg',
#   'alias': 'portillos-hot-dogs-chicago-4',
#   'name': "Portillo's Hot Dogs",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-9jRmNrw7QgjcUn_EXVsEA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/portillos-hot-dogs-chicago-4?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 5526,
#   'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8934295, 'longitude': -87.6314147},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '100 W Ontario',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60654',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['100 W Ontario', 'Chicago, IL 60654']},
#   'phone': '+13125878910',
#   'display_phone': '(312) 587-8910',
#   'distance': 4051.816119735818},
#  {'id': 'pVPyt3TugMd8FW5LGznkQQ',
#   'alias': 'kumas-corner-belmont-chicago',
#   'name': "Kuma's Corner - Belmont",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tczjU01MzXiOMPKY1CEQ0Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kumas-corner-belmont-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 5021,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.939640045166, 'longitude': -87.7004470825195},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '2900 W Belmont Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60618',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2900 W Belmont Ave', 'Chicago, IL 60618']},
#   'phone': '+17736048769',
#   'display_phone': '(773) 604-8769',
#   'distance': 4258.440036134816},
#  {'id': 'xN4e9XY2Z90uEBH3wDDUnQ',
#   'alias': 'paradise-pup-des-plaines',
#   'name': 'Paradise Pup',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bNgZnhPSjro0J9iGiWJsag/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/paradise-pup-des-plaines?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 841,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 42.0221052425779,
#    'longitude': -87.8761289595645},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '1724 S River Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Des Plaines',
#    'zip_code': '60018',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1724 S River Rd', 'Des Plaines, IL 60018']},
#   'phone': '+18476998590',
#   'display_phone': '(847) 699-8590',
#   'distance': 20930.579721130835},
#  {'id': 'Rs2n1VDDD6pkQqexBAJJ0w',
#   'alias': 'hamburger-marys-chicago-2',
#   'name': "Hamburger Mary's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/c02FoFy0A1v13uCVVkaWsQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hamburger-marys-chicago-2?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 995,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 41.97997, 'longitude': -87.66851},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '5400 N Clark St',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60640',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['5400 N Clark St', 'Chicago, IL 60640']},
#   'phone': '+17737846969',
#   'display_phone': '(773) 784-6969',
#   'distance': 8352.899537010202},
#  {'id': '9mhqcimD0CYvqxzfj_VXnQ',
#   'alias': 'little-bad-wolf-chicago',
#   'name': 'Little Bad Wolf',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Cf_ZeAt323eQv83zdhxASA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/little-bad-wolf-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 1529,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.9833823855364,
#    'longitude': -87.6690510144549},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1541 W Bryn Mawr Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60660',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1541 W Bryn Mawr Ave', 'Chicago, IL 60660']},
#   'phone': '+17739426399',
#   'display_phone': '(773) 942-6399',
#   'distance': 8727.811602460897},
#  {'id': 'WJ4ItKGo5Ri2OU6inWMwyQ',
#   'alias': 'top-notch-beef-burgers-chicago',
#   'name': 'Top Notch Beef Burgers',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rYafq5iJvngKL3ldVNfwyg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/top-notch-beef-burgers-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 244,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.7212043666829,
#    'longitude': -87.6754340702493},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2116 W 95th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60643',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2116 W 95th St', 'Chicago, IL 60643']},
#   'phone': '+17734457218',
#   'display_phone': '(773) 445-7218',
#   'distance': 20455.739850496397},
#  {'id': 'aW7sY8DcTKfBFaXIH5vQxQ',
#   'alias': 'lucys-chicago',
#   'name': "Lucy's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TUIkpjAiLpgmRaj9HxgxPg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lucys-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 119,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.90055, 'longitude': -87.69642},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1043 N California Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60622',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1043 N California Ave', 'Chicago, IL 60622']},
#   'phone': '+13126758385',
#   'display_phone': '(312) 675-8385',
#   'distance': 1626.7427753013012},
#  {'id': 'sZ0f3qAYuF9WkHMGD8hBVg',
#   'alias': 'lola-s-coney-island-chicago',
#   'name': 'Lola’s Coney Island',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Uwa-Y2DaS1sGS4BffYsHTw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lola-s-coney-island-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 75,
#   'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 41.8958011238183,
#    'longitude': -87.6989533379674},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '2858 W Chicago Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60622',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2858 W Chicago Ave', 'Chicago, IL 60622']},
#   'phone': '+17736879459',
#   'display_phone': '(773) 687-9459',
#   'distance': 2039.11131286979},
#  {'id': 'ksY97mbEy23n8GbYxOBgpA',
#   'alias': '25-degrees-chicago',
#   'name': '25 Degrees',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QrZkHVeHqHndp2mTaEoqkQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/25-degrees-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 916,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.89595, 'longitude': -87.63159},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '736 N Clark St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60654',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['736 N Clark St', 'Chicago, IL 60654']},
#   'phone': '+13129439700',
#   'display_phone': '(312) 943-9700',
#   'distance': 3957.717670042822},
#  {'id': 'ogpUWakOljukHV2O7A9ulQ',
#   'alias': 'the-graystone-tavern-chicago-2',
#   'name': 'The Graystone Tavern',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QQfmx4AKFid1L-9ILrZmGg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-graystone-tavern-chicago-2?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 68,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.9447779, 'longitude': -87.6539943},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3441 N Sheffield Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60657',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['3441 N Sheffield Ave', 'Chicago, IL 60657']},
#   'phone': '+17736665450',
#   'display_phone': '(773) 666-5450',
#   'distance': 4824.399818987222},
#  {'id': 'mspxW1oelEoo6YJskI5cJg',
#   'alias': 'burger-bar-chicago-south-loop-chicago-6',
#   'name': 'Burger Bar Chicago - South Loop',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/D9oOHJY1EJ5DsUZBujf0OQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/burger-bar-chicago-south-loop-chicago-6?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 636,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.867902, 'longitude': -87.62438},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1150 S Michigan Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60605',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1150 S Michigan Ave', 'Chicago, IL 60605']},
#   'phone': '+13129880162',
#   'display_phone': '(312) 988-0162',
#   'distance': 6057.452136400409},
#  {'id': 'JZNB3CsNgVCRHNDjC-jHkg',
#   'alias': 'highway-house-chicago',
#   'name': 'Highway House',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/U55Gc9p_CaRTUdDksEwVfg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/highway-house-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 138,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.98424, 'longitude': -87.78425},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '5653 N Northwest Hwy',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60646',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['5653 N Northwest Hwy', 'Chicago, IL 60646']},
#   'phone': '+17736573534',
#   'display_phone': '(773) 657-3534',
#   'distance': 12455.172723146015},
#  {'id': 'xifnqqBSPUKu4MHBeVORIg',
#   'alias': 'fresh-stack-burger-kildeer',
#   'name': 'Fresh Stack Burger',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/L-04D9UFiiJW26FyE5IFqw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fresh-stack-burger-kildeer?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 15,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 42.16037, 'longitude': -88.04771},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '20413 N Rand Rd',
#    'address2': 'Ste 108',
#    'address3': '',
#    'city': 'Kildeer',
#    'zip_code': '60074',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['20413 N Rand Rd', 'Ste 108', 'Kildeer, IL 60074']},
#   'phone': '+18478477223',
#   'display_phone': '(847) 847-7223',
#   'distance': 41552.1581137499},
#  {'id': 'FS2cByMa3xS6qaVk-MY_ww',
#   'alias': 'dstrkt-bar-and-grill-chicago',
#   'name': 'DSTRKT Bar & Grill',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9eKxpDIIPY12Vx6qTDL46Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dstrkt-bar-and-grill-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 5,
#   'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.90929, 'longitude': -87.6763},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '1540 N Milwaukee',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60622',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1540 N Milwaukee', 'Chicago, IL 60622']},
#   'phone': '+17733944147',
#   'display_phone': '(773) 394-4147',
#   'distance': 480.7738554723246},
#  {'id': 'XxlGQjRUuYO3LA7XuHZxwA',
#   'alias': 'the-region-chicago',
#   'name': 'The Region',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nfvzqedRwB_BwGwJ9aZM0w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-region-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 172,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.94292, 'longitude': -87.6807},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2057 W Roscoe St',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60618',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2057 W Roscoe St', 'Chicago, IL 60618']},
#   'phone': '+17738572874',
#   'display_phone': '(773) 857-2874',
#   'distance': 4211.421415916358},
#  {'id': 'NBEEgsYm4h9FzK12j4VfHQ',
#   'alias': 'mini-mott-chicago-2',
#   'name': 'Mini Mott',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GAPadElogx84JZyk9MDNCA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mini-mott-chicago-2?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 185,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.927963, 'longitude': -87.704771},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3057 W Logan Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60647',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['3057 W Logan Blvd', 'Chicago, IL 60647']},
#   'phone': '+17739047620',
#   'display_phone': '(773) 904-7620',
#   'distance': 3379.7543352444864},
#  {'id': 'IVeNXvdPQkywMFAb2EPOAA',
#   'alias': 'raymonds-hamburgers-chicago',
#   'name': "Raymond's Hamburgers",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UUfHCoUh6gqqIM2BzsvCVg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/raymonds-hamburgers-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 31,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 41.8516693115234,
#    'longitude': -87.6926193237305},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '2653 W Cermak Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60608',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2653 W Cermak Rd', 'Chicago, IL 60608']},
#   'phone': '+17735791603',
#   'display_phone': '(773) 579-1603',
#   'distance': 6065.962751866825},
#  {'id': 'H4KzoY_z3D3tUnPZMv3HXg',
#   'alias': 'the-burger-point-chicago',
#   'name': 'The Burger Point',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/anPV0LeLDlSr7TvKX8lhhw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-burger-point-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 552,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8562862457147,
#    'longitude': -87.6273884868141},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1900 S State St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60616',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1900 S State St', 'Chicago, IL 60616']},
#   'phone': '+13128421900',
#   'display_phone': '(312) 842-1900',
#   'distance': 6850.31303683385},
#  {'id': 'GEpXn9rtTMtIj5NsGFiNQw',
#   'alias': 'the-bad-apple-chicago',
#   'name': 'The Bad Apple',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mD9OHaj1gy0MWcIusQkPSQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-bad-apple-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 1539,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.959767, 'longitude': -87.682822},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '4300 N Lincoln Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60618',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['4300 N Lincoln Ave', 'Chicago, IL 60618']},
#   'phone': '+17733608406',
#   'display_phone': '(773) 360-8406',
#   'distance': 6086.490547426838},
#  {'id': 'xgxTYYYHaUf3Oly7FAFfYg',
#   'alias': 'manzos-burger-chicago-2',
#   'name': "Manzo's Burger",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BtFs4tep2VE4EfLtAPfrcA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/manzos-burger-chicago-2?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 143,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.691588, 'longitude': -87.680688},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '2353 W 111th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60643',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2353 W 111th St', 'Chicago, IL 60643']},
#   'phone': '+17737795945',
#   'display_phone': '(773) 779-5945',
#   'distance': 23749.249994023772},
#  {'id': '7xpf5VhK73NN3gcb4gbMCA',
#   'alias': 'epic-burger-chicago',
#   'name': 'Epic Burger',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jWmqBu93y9yd_Sct3sJmog/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/epic-burger-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 793,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 41.8752826, 'longitude': -87.6274851},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '517 S State St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60605',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['517 S State St', 'Chicago, IL 60605']},
#   'phone': '+13129131373',
#   'display_phone': '(312) 913-1373',
#   'distance': 5352.217032783875},
#  {'id': 'B4BaXk9lRHeThRZ60yjArQ',
#   'alias': 'nicks-on-north-chicago-2',
#   'name': "Nick's On North",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cJj_Jl5xkAiZVJhwsaFStA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nicks-on-north-chicago-2?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 76,
#   'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'greek', 'title': 'Greek'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.909719, 'longitude': -87.710463},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '3323 W N Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60647',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['3323 W N Ave', 'Chicago, IL 60647']},
#   'phone': '+17734866200',
#   'display_phone': '(773) 486-6200',
#   'distance': 2752.9888541568744},
#  {'id': 'zbdhMq_8OjSZEHyw_PoQBQ',
#   'alias': 'flub-a-dub-chubs-chicago',
#   'name': "Flub A Dub Chub's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/n5je1BafFlYgHsgA3z4lag/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/flub-a-dub-chubs-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 670,
#   'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.93717, 'longitude': -87.64401},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '3021 N Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60657',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['3021 N Broadway', 'Chicago, IL 60657']},
#   'phone': '+17738576500',
#   'display_phone': '(773) 857-6500',
#   'distance': 4522.896348730575},
#  {'id': 'O073WVgzIh5OXRVL9TrRFQ',
#   'alias': 'big-and-littles-restaurant-chicago-4',
#   'name': "BIG & little's Restaurant",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AoyilQQLwxzjEbbW2eatwA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/big-and-littles-restaurant-chicago-4?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 395,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.90535, 'longitude': -87.6700199},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '1310 N Milwaukee Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60622',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1310 N Milwaukee Ave', 'Chicago, IL 60622']},
#   'phone': '+17736987777',
#   'display_phone': '(773) 698-7777',
#   'distance': 650.9924569530984},
#  {'id': 'I93tt83rdE6kJoOPoaaPGA',
#   'alias': 'burger-antics-brookfield',
#   'name': 'Burger Antics',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rO-mDqPBI6_ylUzNcnvRVg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/burger-antics-brookfield?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 587,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.82266, 'longitude': -87.84498},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '3740 Grand Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Brookfield',
#    'zip_code': '60513',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['3740 Grand Blvd', 'Brookfield, IL 60513']},
#   'phone': '+17082555182',
#   'display_phone': '(708) 255-5182',
#   'distance': 16611.223921027024},
#  {'id': 'cnQ2AVaBBHE6365ntgoG5w',
#   'alias': 'chicago-char-grill-chicago',
#   'name': 'Chicago Char Grill',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/B9rhtq_-4Lv2A3q1FqomLA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chicago-char-grill-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 2,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 41.986101, 'longitude': -87.699579},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '5731 N Lincoln Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60659',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['5731 N Lincoln Ave', 'Chicago, IL 60659']},
#   'phone': '+17736543953',
#   'display_phone': '(773) 654-3953',
#   'distance': 9177.35930658358},
#  {'id': 'lMKK_to3ZZ31Ste-ncsJ0Q',
#   'alias': 'small-cheval-wells-chicago',
#   'name': 'Small Cheval - Wells',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/g_91EN_9egHeAhUegPWNsw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/small-cheval-wells-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 228,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.9070377212869, 'longitude': -87.63409},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1345 N Wells St',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60610',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1345 N Wells St', 'Chicago, IL 60610']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 3620.3755228560126},
#  {'id': 'XVNGlpIubrwmUtSLxqmxZw',
#   'alias': 'the-sandlot-park-ridge',
#   'name': 'The Sandlot',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bwikWs8dXyd5oBqMaAkXMQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-sandlot-park-ridge?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 322,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 42.01104, 'longitude': -87.84036},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '1120 W Touhy Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Park Ridge',
#    'zip_code': '60068',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1120 W Touhy Ave', 'Park Ridge, IL 60068']},
#   'phone': '+18476921900',
#   'display_phone': '(847) 692-1900',
#   'distance': 17865.41727480655},
#  {'id': '763ARZeDvQfhXZvkDlKtFw',
#   'alias': 'dmk-burger-bar-chicago',
#   'name': 'DMK Burger Bar',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LB45bmMwR20cwQI8eggzdw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dmk-burger-bar-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 1961,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.936055, 'longitude': -87.65411},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2954 N Sheffield Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60657',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2954 N Sheffield Ave', 'Chicago, IL 60657']},
#   'phone': '+17733608686',
#   'display_phone': '(773) 360-8686',
#   'distance': 3953.815121728274},
#  {'id': 'v6STMYtfNak_vSiqvI3B3Q',
#   'alias': 'dog-haus-biergarten-chicago',
#   'name': 'Dog Haus Biergarten',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EUqBROJbaooj-GBQ0L-LEQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dog-haus-biergarten-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 180,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'hotdog', 'title': 'Hot Dogs'},
#    {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.9267403, 'longitude': -87.6509838},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '2464 N Lincoln Ave',
#    'address2': None,
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60614',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2464 N Lincoln Ave', 'Chicago, IL 60614']},
#   'phone': '+17739353647',
#   'display_phone': '(773) 935-3647',
#   'distance': 3266.339385643194},
#  {'id': '6stI1fteYUDyTxB6ZkRa2w',
#   'alias': 'lulus-hot-dogs-chicago',
#   'name': "Lulu's Hot Dogs",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LB533Cc4I8VfUOzXcnJ_eA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lulus-hot-dogs-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 98,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'hotdog', 'title': 'Hot Dogs'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8688733374583,
#    'longitude': -87.6814892266157},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '1000 S Leavitt St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60612',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1000 S Leavitt St', 'Chicago, IL 60612']},
#   'phone': '+13122433444',
#   'display_phone': '(312) 243-3444',
#   'distance': 4046.5672151671747},
#  {'id': 'ccr996t6e89u6f8XKNXLgA',
#   'alias': 'edzos-burger-shop-evanston',
#   'name': "Edzo's Burger Shop",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1ovqDXHl2QJ2AwzlhPBk-Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/edzos-burger-shop-evanston?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 750,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 42.046047, 'longitude': -87.681241},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1571 Sherman Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Evanston',
#    'zip_code': '60201',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1571 Sherman Ave', 'Evanston, IL 60201']},
#   'phone': '+18478643396',
#   'display_phone': '(847) 864-3396',
#   'distance': 15685.977595699214},
#  {'id': 'kGZHjv8L7sHcJ0tvvxfpYA',
#   'alias': 'grants-wonderburger-chicago',
#   'name': "Grant's Wonderburger",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1bSNcSCQPA08tMbSnoj-4Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/grants-wonderburger-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 40,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 41.6911735484429,
#    'longitude': -87.7042832583419},
#   'transactions': [],
#   'location': {'address1': '3333 W 111th St',
#    'address2': 'Unit B',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60655',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['3333 W 111th St', 'Unit B', 'Chicago, IL 60655']},
#   'phone': '+17736148336',
#   'display_phone': '(773) 614-8336',
#   'distance': 23895.42679915307},
#  {'id': 'FCcgXODBs6O7MGH3VZNyLQ',
#   'alias': 'superdawg-drive-in-chicago-2',
#   'name': 'Superdawg Drive-In',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/b9N7_cOmb7xyD_P5qbWO7w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/superdawg-drive-in-chicago-2?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 1557,
#   'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.9967775833509,
#    'longitude': -87.7870387664546},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '6363 N Milwaukee Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60646',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['6363 N Milwaukee Ave', 'Chicago, IL 60646']},
#   'phone': '+17737630660',
#   'display_phone': '(773) 763-0660',
#   'distance': 13617.863341785609},
#  {'id': 'yTOIHa6SD_TC_3TwM5W4aw',
#   'alias': 'dons-grill-chicago',
#   'name': "Don's Grill",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/T0SHV6Yiu1O4f37A-oljVg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dons-grill-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 63,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.856479, 'longitude': -87.685517},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '1837 S Western Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60686',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1837 S Western Ave', 'Chicago, IL 60686']},
#   'phone': '+13127339351',
#   'display_phone': '(312) 733-9351',
#   'distance': 5450.90494927744},
#  {'id': 'rL3Z28FBnl1tFXoIGPlgtw',
#   'alias': 'shake-shack-chicago',
#   'name': 'Shake Shack',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9UaGSq0cwjn3z55SVNnG9w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/shake-shack-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 1168,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 41.8925451786606, 'longitude': -87.626036489827},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '66 E Ohio St',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60611',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['66 E Ohio St', 'Chicago, IL 60611']},
#   'phone': '+13126671701',
#   'display_phone': '(312) 667-1701',
#   'distance': 4565.330132817699},
#  {'id': '5IRgY9M2lKrBNcnG83DQKw',
#   'alias': 'mikkeys-retro-grill-chicago',
#   'name': "Mikkey's Retro Grill",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CNZx2fhiFWti42UVf0jgbQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mikkeys-retro-grill-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 207,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 41.7991568485298,
#    'longitude': -87.5838662223336},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '5319 S Hyde Park Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60615',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['5319 S Hyde Park Blvd', 'Chicago, IL 60615']},
#   'phone': '+17736758525',
#   'display_phone': '(773) 675-8525',
#   'distance': 14121.484694272895},
#  {'id': '3KEJP9icHNlT_L4Row3lyA',
#   'alias': 'epic-burger-chicago-8',
#   'name': 'Epic Burger',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vRyZFSBV6BiV_NyIqjM8dw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/epic-burger-chicago-8?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 289,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8894953, 'longitude': -87.6310549},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '407 N Clark St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60654',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['407 N Clark St', 'Chicago, IL 60654']},
#   'phone': '+13122390110',
#   'display_phone': '(312) 239-0110',
#   'distance': 4240.285364093777},
#  {'id': 'vKEm5YPvlv_HzRSCtF4cmg',
#   'alias': 'the-crazy-greek-skokie',
#   'name': 'The Crazy Greek',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uebypVNXIfUW7-1_xrc3SA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-crazy-greek-skokie?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 31,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'wraps', 'title': 'Wraps'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 42.02605, 'longitude': -87.75423},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '5051 Oakton St',
#    'address2': None,
#    'address3': '',
#    'city': 'Skokie',
#    'zip_code': '60077',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['5051 Oakton St', 'Skokie, IL 60077']},
#   'phone': '+18479998555',
#   'display_phone': '(847) 999-8555',
#   'distance': 14839.767023967292},
#  {'id': 'jw7nQ8Sg1gx1SgadcL1ZOQ',
#   'alias': 'thats-a-burger-chicago-3',
#   'name': "That's A Burger",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uKuSDyM_xwlKxuoDzCTlig/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/thats-a-burger-chicago-3?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 58,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.7440799, 'longitude': -87.58499},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '8301 S Stony Island Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60617',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['8301 S Stony Island Ave', 'Chicago, IL 60617']},
#   'phone': '+17737216777',
#   'display_phone': '(773) 721-6777',
#   'distance': 19516.7567127491},
#  {'id': 've23JjeBsHzPLRUObdYlyw',
#   'alias': 'victory-grill-chicago',
#   'name': 'Victory Grill',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jCklg78tzUS3xcZJHv9qAQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/victory-grill-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 31,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#    {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.921661, 'longitude': -87.695588},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '2246 N Milwaukee Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60647',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2246 N Milwaukee Ave', 'Chicago, IL 60647']},
#   'phone': '+17736979745',
#   'display_phone': '(773) 697-9745',
#   'distance': 2354.125334145083},
#  {'id': '3_bJTUh5BNaD10s4hZUcjQ',
#   'alias': 'patinos-grill-chicago',
#   'name': "Patino's Grill",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/V06xzByy2kPBxsmmbiUweQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/patinos-grill-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 187,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.953742, 'longitude': -87.706068},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '3109 W Irving Park Rd',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60618',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['3109 W Irving Park Rd', 'Chicago, IL 60618']},
#   'phone': '+17736543453',
#   'display_phone': '(773) 654-3453',
#   'distance': 5887.724175553893},
#  {'id': 'nQ1Y0sH_A8NFLB4eI_O5UQ',
#   'alias': 'hamburger-stans-revival-food-hall-chicago',
#   'name': 'Hamburger Stans - Revival Food Hall',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4EkiM7o3Z4iMUgJ_sFkmKQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hamburger-stans-revival-food-hall-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 4,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.879792, 'longitude': -87.63032},
#   'transactions': [],
#   'location': {'address1': '125 S Clark St',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['125 S Clark St', 'Chicago, IL 60603']},
#   'phone': '+17739999411',
#   'display_phone': '(773) 999-9411',
#   'distance': 4835.190179051248},
#  {'id': 'vvc8AmPruXgRDr7qBZO80Q',
#   'alias': 'maxwell-street-depot-chicago',
#   'name': 'Maxwell Street Depot',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2K8JmfXtq2dsuC3rw51hQw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/maxwell-street-depot-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 159,
#   'categories': [{'alias': 'diners', 'title': 'Diners'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.838049703686, 'longitude': -87.6371533103465},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '411 W 31st St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60616',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['411 W 31st St', 'Chicago, IL 60616']},
#   'phone': '+13123263514',
#   'display_phone': '(312) 326-3514',
#   'distance': 8184.8864254332175},
#  {'id': 'uurF1XPjdAdBOlI1g_WuUQ',
#   'alias': 'charlys-burgers-chicago',
#   'name': "Charly's Burgers",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8_qbdKqsCOrd7iSykLM8IA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/charlys-burgers-chicago?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#   'review_count': 12,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.9231177978453,
#    'longitude': -87.7464619651437},
#   'transactions': ['delivery'],
#   'location': {'address1': '2320 N Cicero Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60639',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2320 N Cicero Ave', 'Chicago, IL 60639']},
#   'phone': '+17738875481',
#   'display_phone': '(773) 887-5481',
#   'distance': 6024.906668077671}]

# %% [markdown]
# ## Breaking Down the Request
#
# As you can see, there are three main parts to our request.
#
# They are:
# * The url
# * The header
# * The parameters
#
# The url is fairly straightforward and is simply the base url as described in the documentation.
#
# The header is a dictionary of key-value pairs. In this case, we are using a fairly standard header used by many APIs. It has a strict form where 'Authorization' is the key and 'Bearer YourApiKey' is the value.
#
# The parameters are the filters which we wish to pass into the query. These will be embedded into the url when the request is made to the api. Similar to the header, they form key-value pairs. Valid key parameters by which to structure your queries, are described in the API documentation which we'll look at further shortly. A final important note however, is the need to replace spaces with "+". This is standard to many requests as URLs cannot contain spaces. (Note that the header itself isn't directly embedded into the url itself and as such, the space between 'Bearer' and YourApiKey is valid.)

# %% [markdown]
# ## The Response
#
# As before, our response object has both a status code, as well as the data itself. With that, let's start with a little data exploration!

# %%
response.json().keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %% [markdown]
# Now let's go a bit further and start to preview what's stored in each of the values for these keys.

# %%
for key in response.json().keys():
    print(key)
    value = response.json()[key] 
    print(type(value), sep="\n\n")
# Out:
# businesses
# <class 'list'>
# total
# <class 'int'>
# region
# <class 'dict'>

# %% [markdown]
# Let's continue to preview these further to get a little better acquainted.

# %%
yelp_data =response.json()

yelp_data['businesses'][0]
# Out:
# {'id': '7Es7EbTy_s1btAdowLeiPQ',
#  'alias': 'small-cheval-chicago-2',
#  'name': 'Small Cheval',
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/trovJn8N69SnqlaQyLfdUQ/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/small-cheval-chicago-2?adjust_creative=y4uJtEuFxNMBfKIqOyxUTw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y4uJtEuFxNMBfKIqOyxUTw',
#  'review_count': 1098,
#  'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#   {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': 41.91282, 'longitude': -87.6815699},
#  'transactions': ['pickup', 'delivery'],
#  'price': '$$',
#  'location': {'address1': '1732 N Milwaukee Ave',
#   'address2': None,
#   'address3': '',
#   'city': 'Chicago',
#   'zip_code': '60647',
#   'country': 'US',
#   'state': 'IL',
#   'display_address': ['1732 N Milwaukee Ave', 'Chicago, IL 60647']},
#  'phone': '+13129294580',
#  'display_phone': '(312) 929-4580',
#  'distance': 904.5895233591364}

# %%
df = pd.DataFrame(yelp_data['businesses'])

df.head()
# Out:
#                        id                           alias  \
# 0  7Es7EbTy_s1btAdowLeiPQ          small-cheval-chicago-2
# 1  xoi7Cw7FoknAx5p880RtWQ               au-cheval-chicago
# 2  GbC6XO60SlLnlIOTbJE-Ew     fatsos-last-stand-chicago-2
# 3  zEBMoH7ibF3YZrlowkv88A             brgrbelly-chicago-3
# 4  Ydf5dgFsGhMSP61Ht7TekA  butcher-and-the-burger-chicago
#
#                    name                                          image_url  \
# 0          Small Cheval  https://s3-media2.fl.yelpcdn.com/bphoto/trovJn...
# 1             Au Cheval  https://s3-media4.fl.yelpcdn.com/bphoto/a0yhvS...
# 2    Fatso's Last Stand  https://s3-media2.fl.yelpcdn.com/bphoto/QLIfu2...
# 3             BRGRBELLY  https://s3-media1.fl.yelpcdn.com/bphoto/ymFcfc...
# 4  Butcher & The Burger  https://s3-media2.fl.yelpcdn.com/bphoto/XrovZl...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/small-cheval-chicago-...          1098
# 1      False  https://www.yelp.com/biz/au-cheval-chicago?adj...          7087
# 2      False  https://www.yelp.com/biz/fatsos-last-stand-chi...           791
# 3      False  https://www.yelp.com/biz/brgrbelly-chicago-3?a...           543
# 4      False  https://www.yelp.com/biz/butcher-and-the-burge...          1018
#
#                                           categories  rating  \
# 0  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.5
# 1  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.5
# 2  [{'alias': 'hotdog', 'title': 'Hot Dogs'}, {'a...     4.0
# 3  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.5
# 4  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.0
#
#                                          coordinates        transactions  \
# 0   {'latitude': 41.91282, 'longitude': -87.6815699}  [pickup, delivery]
# 1    {'latitude': 41.88466, 'longitude': -87.647668}  [pickup, delivery]
# 2  {'latitude': 41.8959792096669, 'longitude': -8...  [pickup, delivery]
# 3  {'latitude': 41.9530335, 'longitude': -87.7709...  [pickup, delivery]
# 4     {'latitude': 41.91787, 'longitude': -87.65423}  [pickup, delivery]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '1732 N Milwaukee Ave', 'address2...  +13129294580
# 1    $$  {'address1': '800 W Randolph St', 'address2': ...  +13129294580
# 2    $$  {'address1': '2258 W Chicago Ave', 'address2':...  +17732453287
# 3    $$  {'address1': '5739 W Irving Park Rd', 'address...  +17732837880
# 4    $$  {'address1': '1021 W Armitage Ave', 'address2'...  +17736973735
#
#     display_phone     distance
# 0  (312) 929-4580   904.589523
# 1  (312) 929-4580  3376.598427
# 2  (773) 245-3287  1153.591186
# 3  (773) 283-7880  9370.400183
# 4  (773) 697-3735  2403.833030

# %%
lat = [float(business['coordinates']['latitude']) for business in yelp_data['businesses']]
long = [float(business['coordinates']['longitude']) for  business in yelp_data['businesses']]
df['lat'] = lat
df['long'] = long

# %%
df.head()
# Out:
#                        id                           alias  \
# 0  7Es7EbTy_s1btAdowLeiPQ          small-cheval-chicago-2
# 1  xoi7Cw7FoknAx5p880RtWQ               au-cheval-chicago
# 2  GbC6XO60SlLnlIOTbJE-Ew     fatsos-last-stand-chicago-2
# 3  zEBMoH7ibF3YZrlowkv88A             brgrbelly-chicago-3
# 4  Ydf5dgFsGhMSP61Ht7TekA  butcher-and-the-burger-chicago
#
#                    name                                          image_url  \
# 0          Small Cheval  https://s3-media2.fl.yelpcdn.com/bphoto/trovJn...
# 1             Au Cheval  https://s3-media4.fl.yelpcdn.com/bphoto/a0yhvS...
# 2    Fatso's Last Stand  https://s3-media2.fl.yelpcdn.com/bphoto/QLIfu2...
# 3             BRGRBELLY  https://s3-media1.fl.yelpcdn.com/bphoto/ymFcfc...
# 4  Butcher & The Burger  https://s3-media2.fl.yelpcdn.com/bphoto/XrovZl...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/small-cheval-chicago-...          1098
# 1      False  https://www.yelp.com/biz/au-cheval-chicago?adj...          7087
# 2      False  https://www.yelp.com/biz/fatsos-last-stand-chi...           791
# 3      False  https://www.yelp.com/biz/brgrbelly-chicago-3?a...           543
# 4      False  https://www.yelp.com/biz/butcher-and-the-burge...          1018
#
#                                           categories  rating  \
# 0  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.5
# 1  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.5
# 2  [{'alias': 'hotdog', 'title': 'Hot Dogs'}, {'a...     4.0
# 3  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.5
# 4  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.0
#
#                                          coordinates        transactions  \
# 0   {'latitude': 41.91282, 'longitude': -87.6815699}  [pickup, delivery]
# 1    {'latitude': 41.88466, 'longitude': -87.647668}  [pickup, delivery]
# 2  {'latitude': 41.8959792096669, 'longitude': -8...  [pickup, delivery]
# 3  {'latitude': 41.9530335, 'longitude': -87.7709...  [pickup, delivery]
# 4     {'latitude': 41.91787, 'longitude': -87.65423}  [pickup, delivery]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '1732 N Milwaukee Ave', 'address2...  +13129294580
# 1    $$  {'address1': '800 W Randolph St', 'address2': ...  +13129294580
# 2    $$  {'address1': '2258 W Chicago Ave', 'address2':...  +17732453287
# 3    $$  {'address1': '5739 W Irving Park Rd', 'address...  +17732837880
# 4    $$  {'address1': '1021 W Armitage Ave', 'address2'...  +17736973735
#
#     display_phone     distance        lat       long
# 0  (312) 929-4580   904.589523  41.912820 -87.681570
# 1  (312) 929-4580  3376.598427  41.884660 -87.647668
# 2  (773) 245-3287  1153.591186  41.895979 -87.684258
# 3  (773) 283-7880  9370.400183  41.953033 -87.770982
# 4  (773) 697-3735  2403.833030  41.917870 -87.654230
